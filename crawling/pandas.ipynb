# %%
import pandas as pd

df1 = pd.DataFrame(
    {
        "이름" : ["손흥민", '메시', '호날두'],
        "나이" : [30, 35, 40],
        "소속": ['토트넘', '바르셀로나', '유벤투스']
    }
)
player_list = [
    ['손흥민', 30, '토트넘'],
    ['메시', 35, '바르셀로나'],
    ['호날두', 40, '유벤투스']
    ]
df2 = pd.DataFrame(player_list, columns=['이름', '나이', '소속'])

print(df1)
print(df2)
# Out:
#     이름  나이     소속
# 0  손흥민  30    토트넘
# 1   메시  35  바르셀로나
# 2  호날두  40   유벤투스
#     이름  나이     소속
# 0  손흥민  30    토트넘
# 1   메시  35  바르셀로나
# 2  호날두  40   유벤투스
